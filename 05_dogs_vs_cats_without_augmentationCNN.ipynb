# %% [markdown]
# #### Dogs vs Cats Image Classification Without Image Augmentation
#
# We'll build an image classifier using tf.keras.Sequential model and load data using tf.keras.preprocessing.image.ImageDataGenerator
#
# In the process, we will build practical experience and develop intuition around the following concepts
#
# - Building data input pipelines using the tf.keras.preprocessing.image.ImageDataGenerator class — How can we efficiently work with data on disk to interface with our model?
# - Overfitting - what is it, how to identify it?

# %%
#### importing packages

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os 
import matplotlib.pyplot as plt
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# #### Data Loading
# To build our image classifier, we begin by downloading the dataset. The dataset we are using is a filtered version of Dogs vs. Cats dataset from Kaggle (ultimately, this dataset is provided by Microsoft Research).
#
# In previous Colabs, we've used TensorFlow Datasets, which is a very easy and convenient way to use datasets. In this Colab however, we will make use of the class tf.keras.preprocessing.image.ImageDataGenerator which will read data from disk. We therefore need to directly download Dogs vs. Cats from a URL and unzip it to the Colab filesystem.

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 1s 0us/step

# %% [markdown]
# We can list the directories with the following terminal command:

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs

# %% [markdown]
# We'll now assign variables with the proper file path for the training and validation sets.

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures

# %% [markdown]
# #### Understanding our data
# Let's look at how many cats and dogs images we have in our training and validation directory

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# ### Setting Model Parameters
# For convenience, we'll set up variables that will be used later while pre-processing our dataset and training our network.

# %%
BATCH_SIZE = 100  # Number of training examples to process before updating our models variables
IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %% [markdown]
# #### Data Preparation
# Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network. The steps involved in preparing these images are:
#
# 1. Read images from the disk
# 2. Decode contents of these images and convert it into proper grid format as per their RGB content
# 3. Convert them into floating point tensors
# 4. Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.
# Fortunately, all these tasks can be done using the class tf.keras.preprocessing.image.ImageDataGenerator.
#
# We can set this up in a couple of lines of code.

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# After defining our generators for training and validation images, flow_from_directory method will load images from the disk, apply rescaling, and resize them using single line of code.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True, ## set to true as we don't algo to memorise train data 
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# #### Visualizing Training images
# We can visualize our training images by getting a batch of images from the training generator, and then plotting a few of them using matplotlib.

# %%
sample_training_images, _ = next(train_data_gen)

# %% [markdown]
# The next function returns a batch from the dataset. One batch is a tuple of (many images, many labels). For right now, we're discarding the labels because we just want to look at the images.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.

def plotImages(images_arr):
  fig,axes = plt.subplots(1,5,figsize=(20,20))
  axes =axes.flatten()
  for img,ax in zip(images_arr,axes):
    ax.imshow(img)
  plt.tight_layout()
  plt.show()

# %%
plotImages(sample_training_images[:5])  # Plot images 0-4

# %% [markdown]
# #### Model Creation
#
# ### Define the model
# The model consists of four convolution blocks with a max pool layer in each of them. Then we have a fully connected layer with 512 units, with a relu activation function.
#
# The model will output class probabilities for two classes — dogs and cats — using softmax.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3) , activation='relu' , input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %% [markdown]
# ### Compile the model
#
# As usual, we will use the adam optimizer. Since we output a softmax categorization, we'll use sparse_categorical_crossentropy as the loss function. We would also like to look at training and validation accuracy on each epoch as we train our network, so we are passing in the metrics argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### Model Summary
# Let's look at all the layers of our network using summary method.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the model
# It's time we train our network.
#
# Since our batches are coming from a generator (ImageDataGenerator), we'll use fit_generator instead of fit.

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 9s 443ms/step - loss: 0.7038 - accuracy: 0.5240 - val_loss: 0.6862 - val_accuracy: 0.5020
# Epoch 2/100
# 20/20 [==============================] - 9s 440ms/step - loss: 0.6843 - accuracy: 0.5605 - val_loss: 0.6728 - val_accuracy: 0.6310
# Epoch 3/100
# 20/20 [==============================] - 9s 431ms/step - loss: 0.6615 - accuracy: 0.6220 - val_loss: 0.6509 - val_accuracy: 0.6090
# Epoch 4/100
# 20/20 [==============================] - 9s 428ms/step - loss: 0.6056 - accuracy: 0.6775 - val_loss: 0.5995 - val_accuracy: 0.6760
# Epoch 5/100
# 20/20 [==============================] - 9s 429ms/step - loss: 0.5532 - accuracy: 0.7135 - val_loss: 0.5718 - val_accuracy: 0.7090
# Epoch 6/100
# 20/20 [==============================] - 9s 428ms/step - loss: 0.5131 - accuracy: 0.7410 - val_loss: 0.5395 - val_accuracy: 0.7180
# Epoch 7/100
# 20/20 [==============================] - 9s 428ms/step - loss: 0.4730 - accuracy: 0.7715 - val_loss: 0.5798 - val_accuracy: 0.7030
# Epoch 8/100
# 20/20 [==============================] - 9s 429ms/step - loss: 0.4555 - accuracy: 0.7815 - val_loss: 0.5669 - val_accuracy: 0.7160
# Epoch 9/100
# 20/20 [==============================] - 9s 431ms/step - loss: 0.4122 - accuracy: 0.8060 - val_loss: 0.5484 - val_accuracy: 0.7380
# Epoch 10/100
# 20/20 [==============================] - 8s 422ms/step - loss: 0.3578 - accuracy: 0.8385 - val_loss: 0.5859 - val_accuracy: 0.7370
# Epoch 11/100
# 20/20 [==============================] - 9s 428ms/step - loss: 0.3106 - accuracy: 0.8630 - val_loss: 0.5840 - val_accuracy: 0.7480
# Epoch 12/100
# 20/20 [==============================] - 9s 427ms/step - loss: 0.2702 - accuracy: 0.8905 - val_loss: 0.5999 - val_accuracy: 0.7440
# Epoch 13/100
# 20/20 [==============================] - 9s 440ms/step - loss: 0.2182 - accuracy: 0.9120 - val_loss: 0.6609 - val_accuracy: 0.7430
# Epoch 14/100
# 20/20 [==============================] - 9s 431ms/step - loss: 0.1961 - accuracy: 0.9215 - val_loss: 0.6504 - val_accuracy: 0.7270
# Epoch 15/100
# 20/20 [==============================] - 8s 424ms/step - loss: 0.1641 - accuracy: 0.9345 - val_loss: 0.7227 - val_accuracy: 0.7380
# Epoch 16/100
# 20/20 [==============================] - 9s 432ms/step - loss: 0.1324 - accuracy: 0.9555 - val_loss: 0.7393 - val_accuracy: 0.7550
# Epoch 17/100
# 20/20 [==============================] - 9s 430ms/step - loss: 0.0771 - accuracy: 0.9700 - val_loss: 0.8787 - val_accuracy: 0.7600
# Epoch 18/100
# 20/20 [==============================] - 9s 425ms/step - loss: 0.0640 - accuracy: 0.9770 - val_loss: 0.9621 - val_accuracy: 0.7470
# Epoch 19/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.0344 - accuracy: 0.9895 - val_loss: 1.0762 - val_accuracy: 0.7650
# Epoch 20/100
# 20/20 [==============================] - 8s 424ms/step - loss: 0.0315 - accuracy: 0.9910 - val_loss: 1.0779 - val_accuracy: 0.7410
# Epoch 21/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 1.1278 - val_accuracy: 0.7590
# Epoch 22/100
# 20/20 [==============================] - 9s 425ms/step - loss: 0.0104 - accuracy: 0.9985 - val_loss: 1.2158 - val_accuracy: 0.7530
# Epoch 23/100
# 20/20 [==============================] - 9s 428ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 1.2701 - val_accuracy: 0.7600
# Epoch 24/100
# 20/20 [==============================] - 9s 432ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 1.4000 - val_accuracy: 0.7640
# Epoch 25/100
# 20/20 [==============================] - 9s 435ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.3820 - val_accuracy: 0.7590
# Epoch 26/100
# 20/20 [==============================] - 9s 430ms/step - loss: 8.1467e-04 - accuracy: 1.0000 - val_loss: 1.4177 - val_accuracy: 0.7620
# Epoch 27/100
# 20/20 [==============================] - 9s 430ms/step - loss: 5.1596e-04 - accuracy: 1.0000 - val_loss: 1.4586 - val_accuracy: 0.7680
# Epoch 28/100
# 20/20 [==============================] - 9s 428ms/step - loss: 4.1069e-04 - accuracy: 1.0000 - val_loss: 1.4921 - val_accuracy: 0.7680
# Epoch 29/100
# 20/20 [==============================] - 8s 425ms/step - loss: 3.5449e-04 - accuracy: 1.0000 - val_loss: 1.5213 - val_accuracy: 0.7680
# Epoch 30/100
# 20/20 [==============================] - 8s 423ms/step - loss: 3.0804e-04 - accuracy: 1.0000 - val_loss: 1.5470 - val_accuracy: 0.7690
# Epoch 31/100
# 20/20 [==============================] - 8s 425ms/step - loss: 2.7609e-04 - accuracy: 1.0000 - val_loss: 1.5687 - val_accuracy: 0.7690
# Epoch 32/100
# 20/20 [==============================] - 9s 427ms/step - loss: 2.4776e-04 - accuracy: 1.0000 - val_loss: 1.5865 - val_accuracy: 0.7710
# Epoch 33/100
# 20/20 [==============================] - 8s 423ms/step - loss: 2.2499e-04 - accuracy: 1.0000 - val_loss: 1.6079 - val_accuracy: 0.7720
# Epoch 34/100
# 20/20 [==============================] - 9s 426ms/step - loss: 2.0596e-04 - accuracy: 1.0000 - val_loss: 1.6236 - val_accuracy: 0.7720
# Epoch 35/100
# 20/20 [==============================] - 9s 429ms/step - loss: 1.8732e-04 - accuracy: 1.0000 - val_loss: 1.6417 - val_accuracy: 0.7710
# Epoch 36/100
# 20/20 [==============================] - 9s 427ms/step - loss: 1.7253e-04 - accuracy: 1.0000 - val_loss: 1.6537 - val_accuracy: 0.7690
# Epoch 37/100
# 20/20 [==============================] - 9s 434ms/step - loss: 1.5873e-04 - accuracy: 1.0000 - val_loss: 1.6704 - val_accuracy: 0.7710
# Epoch 38/100
# 20/20 [==============================] - 9s 432ms/step - loss: 1.4703e-04 - accuracy: 1.0000 - val_loss: 1.6862 - val_accuracy: 0.7750
# Epoch 39/100
# 20/20 [==============================] - 9s 428ms/step - loss: 1.3513e-04 - accuracy: 1.0000 - val_loss: 1.6986 - val_accuracy: 0.7740
# Epoch 40/100
# 20/20 [==============================] - 8s 425ms/step - loss: 1.2606e-04 - accuracy: 1.0000 - val_loss: 1.7114 - val_accuracy: 0.7740
# Epoch 41/100
# 20/20 [==============================] - 8s 421ms/step - loss: 1.1670e-04 - accuracy: 1.0000 - val_loss: 1.7233 - val_accuracy: 0.7740
# Epoch 42/100
# 20/20 [==============================] - 8s 421ms/step - loss: 1.0970e-04 - accuracy: 1.0000 - val_loss: 1.7367 - val_accuracy: 0.7760
# Epoch 43/100
# 20/20 [==============================] - 9s 427ms/step - loss: 1.0398e-04 - accuracy: 1.0000 - val_loss: 1.7480 - val_accuracy: 0.7750
# Epoch 44/100
# 20/20 [==============================] - 8s 425ms/step - loss: 9.6801e-05 - accuracy: 1.0000 - val_loss: 1.7559 - val_accuracy: 0.7740
# Epoch 45/100
# 20/20 [==============================] - 8s 423ms/step - loss: 9.0260e-05 - accuracy: 1.0000 - val_loss: 1.7675 - val_accuracy: 0.7740
# Epoch 46/100
# 20/20 [==============================] - 9s 431ms/step - loss: 8.4578e-05 - accuracy: 1.0000 - val_loss: 1.7775 - val_accuracy: 0.7750
# Epoch 47/100
# 20/20 [==============================] - 8s 423ms/step - loss: 7.9664e-05 - accuracy: 1.0000 - val_loss: 1.7875 - val_accuracy: 0.7750
# Epoch 48/100
# 20/20 [==============================] - 9s 426ms/step - loss: 7.5549e-05 - accuracy: 1.0000 - val_loss: 1.7977 - val_accuracy: 0.7730
# Epoch 49/100
# 20/20 [==============================] - 8s 422ms/step - loss: 7.2091e-05 - accuracy: 1.0000 - val_loss: 1.8062 - val_accuracy: 0.7740
# Epoch 50/100
# 20/20 [==============================] - 8s 416ms/step - loss: 6.8408e-05 - accuracy: 1.0000 - val_loss: 1.8151 - val_accuracy: 0.7740
# Epoch 51/100
# 20/20 [==============================] - 8s 420ms/step - loss: 6.4743e-05 - accuracy: 1.0000 - val_loss: 1.8256 - val_accuracy: 0.7730
# Epoch 52/100
# 20/20 [==============================] - 9s 431ms/step - loss: 6.2032e-05 - accuracy: 1.0000 - val_loss: 1.8317 - val_accuracy: 0.7720
# Epoch 53/100
# 20/20 [==============================] - 9s 430ms/step - loss: 5.9266e-05 - accuracy: 1.0000 - val_loss: 1.8407 - val_accuracy: 0.7720
# Epoch 54/100
# 20/20 [==============================] - 8s 421ms/step - loss: 5.6733e-05 - accuracy: 1.0000 - val_loss: 1.8489 - val_accuracy: 0.7720
# Epoch 55/100
# 20/20 [==============================] - 8s 421ms/step - loss: 5.4236e-05 - accuracy: 1.0000 - val_loss: 1.8575 - val_accuracy: 0.7710
# Epoch 56/100
# 20/20 [==============================] - 8s 424ms/step - loss: 5.1357e-05 - accuracy: 1.0000 - val_loss: 1.8643 - val_accuracy: 0.7710
# Epoch 57/100
# 20/20 [==============================] - 8s 419ms/step - loss: 4.9207e-05 - accuracy: 1.0000 - val_loss: 1.8716 - val_accuracy: 0.7720
# Epoch 58/100
# 20/20 [==============================] - 8s 420ms/step - loss: 4.7241e-05 - accuracy: 1.0000 - val_loss: 1.8786 - val_accuracy: 0.7710
# Epoch 59/100
# 20/20 [==============================] - 9s 426ms/step - loss: 4.5278e-05 - accuracy: 1.0000 - val_loss: 1.8864 - val_accuracy: 0.7710
# Epoch 60/100
# 20/20 [==============================] - 8s 420ms/step - loss: 4.3347e-05 - accuracy: 1.0000 - val_loss: 1.8929 - val_accuracy: 0.7710
# Epoch 61/100
# 20/20 [==============================] - 8s 416ms/step - loss: 4.1873e-05 - accuracy: 1.0000 - val_loss: 1.9005 - val_accuracy: 0.7700
# Epoch 62/100
# 20/20 [==============================] - 8s 423ms/step - loss: 4.0395e-05 - accuracy: 1.0000 - val_loss: 1.9090 - val_accuracy: 0.7720
# Epoch 63/100
# 20/20 [==============================] - 9s 427ms/step - loss: 3.8889e-05 - accuracy: 1.0000 - val_loss: 1.9122 - val_accuracy: 0.7700
# Epoch 64/100
# 20/20 [==============================] - 8s 414ms/step - loss: 3.7560e-05 - accuracy: 1.0000 - val_loss: 1.9198 - val_accuracy: 0.7700
# Epoch 65/100
# 20/20 [==============================] - 8s 411ms/step - loss: 3.5802e-05 - accuracy: 1.0000 - val_loss: 1.9275 - val_accuracy: 0.7730
# Epoch 66/100
# 20/20 [==============================] - 8s 422ms/step - loss: 3.4614e-05 - accuracy: 1.0000 - val_loss: 1.9328 - val_accuracy: 0.7690
# Epoch 67/100
# 20/20 [==============================] - 8s 415ms/step - loss: 3.3315e-05 - accuracy: 1.0000 - val_loss: 1.9393 - val_accuracy: 0.7720
# Epoch 68/100
# 20/20 [==============================] - 8s 413ms/step - loss: 3.2086e-05 - accuracy: 1.0000 - val_loss: 1.9438 - val_accuracy: 0.7690
# Epoch 69/100
# 20/20 [==============================] - 8s 415ms/step - loss: 3.1059e-05 - accuracy: 1.0000 - val_loss: 1.9512 - val_accuracy: 0.7730
# Epoch 70/100
# 20/20 [==============================] - 8s 424ms/step - loss: 3.0094e-05 - accuracy: 1.0000 - val_loss: 1.9557 - val_accuracy: 0.7690
# Epoch 71/100
# 20/20 [==============================] - 8s 424ms/step - loss: 2.9314e-05 - accuracy: 1.0000 - val_loss: 1.9632 - val_accuracy: 0.7700
# Epoch 72/100
# 20/20 [==============================] - 9s 428ms/step - loss: 2.8043e-05 - accuracy: 1.0000 - val_loss: 1.9679 - val_accuracy: 0.7670
# Epoch 73/100
# 20/20 [==============================] - 9s 432ms/step - loss: 2.7188e-05 - accuracy: 1.0000 - val_loss: 1.9736 - val_accuracy: 0.7670
# Epoch 74/100
# 20/20 [==============================] - 8s 425ms/step - loss: 2.6361e-05 - accuracy: 1.0000 - val_loss: 1.9790 - val_accuracy: 0.7680
# Epoch 75/100
# 20/20 [==============================] - 8s 418ms/step - loss: 2.5574e-05 - accuracy: 1.0000 - val_loss: 1.9852 - val_accuracy: 0.7690
# Epoch 76/100
# 20/20 [==============================] - 9s 425ms/step - loss: 2.4650e-05 - accuracy: 1.0000 - val_loss: 1.9899 - val_accuracy: 0.7680
# Epoch 77/100
# 20/20 [==============================] - 8s 424ms/step - loss: 2.4057e-05 - accuracy: 1.0000 - val_loss: 1.9953 - val_accuracy: 0.7650
# Epoch 78/100
# 20/20 [==============================] - 8s 423ms/step - loss: 2.3318e-05 - accuracy: 1.0000 - val_loss: 1.9999 - val_accuracy: 0.7690
# Epoch 79/100
# 20/20 [==============================] - 9s 426ms/step - loss: 2.2714e-05 - accuracy: 1.0000 - val_loss: 2.0055 - val_accuracy: 0.7660
# Epoch 80/100
# 20/20 [==============================] - 8s 421ms/step - loss: 2.2105e-05 - accuracy: 1.0000 - val_loss: 2.0100 - val_accuracy: 0.7660
# Epoch 81/100
# 20/20 [==============================] - 9s 425ms/step - loss: 2.1342e-05 - accuracy: 1.0000 - val_loss: 2.0156 - val_accuracy: 0.7670
# Epoch 82/100
# 20/20 [==============================] - 8s 421ms/step - loss: 2.0632e-05 - accuracy: 1.0000 - val_loss: 2.0209 - val_accuracy: 0.7670
# Epoch 83/100
# 20/20 [==============================] - 8s 415ms/step - loss: 2.0090e-05 - accuracy: 1.0000 - val_loss: 2.0252 - val_accuracy: 0.7650
# Epoch 84/100
# 20/20 [==============================] - 8s 417ms/step - loss: 1.9588e-05 - accuracy: 1.0000 - val_loss: 2.0306 - val_accuracy: 0.7680
# Epoch 85/100
# 20/20 [==============================] - 8s 422ms/step - loss: 1.9067e-05 - accuracy: 1.0000 - val_loss: 2.0357 - val_accuracy: 0.7670
# Epoch 86/100
# 20/20 [==============================] - 8s 414ms/step - loss: 1.8493e-05 - accuracy: 1.0000 - val_loss: 2.0409 - val_accuracy: 0.7680
# Epoch 87/100
# 20/20 [==============================] - 8s 417ms/step - loss: 1.7969e-05 - accuracy: 1.0000 - val_loss: 2.0459 - val_accuracy: 0.7670
# Epoch 88/100
# 20/20 [==============================] - 9s 428ms/step - loss: 1.7518e-05 - accuracy: 1.0000 - val_loss: 2.0502 - val_accuracy: 0.7660
# Epoch 89/100
# 20/20 [==============================] - 8s 418ms/step - loss: 1.7159e-05 - accuracy: 1.0000 - val_loss: 2.0557 - val_accuracy: 0.7670
# Epoch 90/100
# 20/20 [==============================] - 8s 423ms/step - loss: 1.6542e-05 - accuracy: 1.0000 - val_loss: 2.0583 - val_accuracy: 0.7650
# Epoch 91/100
# 20/20 [==============================] - 8s 425ms/step - loss: 1.6169e-05 - accuracy: 1.0000 - val_loss: 2.0644 - val_accuracy: 0.7670
# Epoch 92/100
# 20/20 [==============================] - 9s 426ms/step - loss: 1.5806e-05 - accuracy: 1.0000 - val_loss: 2.0685 - val_accuracy: 0.7670
# Epoch 93/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.5316e-05 - accuracy: 1.0000 - val_loss: 2.0728 - val_accuracy: 0.7670
# Epoch 94/100
# 20/20 [==============================] - 9s 430ms/step - loss: 1.5026e-05 - accuracy: 1.0000 - val_loss: 2.0771 - val_accuracy: 0.7660
# Epoch 95/100
# 20/20 [==============================] - 8s 425ms/step - loss: 1.4583e-05 - accuracy: 1.0000 - val_loss: 2.0823 - val_accuracy: 0.7670
# Epoch 96/100
# 20/20 [==============================] - 8s 413ms/step - loss: 1.4300e-05 - accuracy: 1.0000 - val_loss: 2.0858 - val_accuracy: 0.7670
# Epoch 97/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.3912e-05 - accuracy: 1.0000 - val_loss: 2.0902 - val_accuracy: 0.7660
# Epoch 98/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.3538e-05 - accuracy: 1.0000 - val_loss: 2.0946 - val_accuracy: 0.7660
# Epoch 99/100
# 20/20 [==============================] - 8s 409ms/step - loss: 1.3250e-05 - accuracy: 1.0000 - val_loss: 2.0975 - val_accuracy: 0.7670
# Epoch 100/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.2929e-05 - accuracy: 1.0000 - val_loss: 2.1027 - val_accuracy: 0.7670

# %% [markdown]
# #### Visualizing results of the training
# We'll now visualize the results we get after training our network.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %% [markdown]
# As we can see from the plots, training accuracy and validation accuracy are off by large margin and our model has achieved only around 70% accuracy on the validation set (depending on the number of epochs you trained for).
#
# This is a clear indication of overfitting. Once the training and validation curves start to diverge, our model has started to memorize the training data and is unable to perform well on the validation data.
